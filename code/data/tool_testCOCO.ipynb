# %%
# 验证COCO
# 需要修改下面的数据路径
from pycocotools.coco import COCO
import cv2
import os
import pandas as pd
import numpy as np
 
 
def showNimages(annFile, imageFile, resultFile):
    """
    :param imageidFile: 要查看的图片imageid，存储一列在csv文件里 （目前设计的imageid需要为6位数，如果少于6位数，可以在前面加多个0）
    :param annFile:使用的标注文件
    :param imageFile:要读取的image所在文件夹
    :param resultFile:画了标注之后的image存储文件夹
    :return:
    """
    # data = pd.read_csv(imageidFile)
    # list = data.values.tolist()
    image_id = []  # 存储的是要提取图片id
    # for i in range(len(list)):
    #     image_id.append(list[i][0])
    image_id.append(int(1))
    image_id.append(304142)

#     image_id.append(int(100))

    coco = COCO(annFile)
 
    for i in range(len(image_id)):
        imageIds = coco.getImgIds(imgIds=image_id[i])
        images = coco.load_imgs(imageIds)
        annIds = coco.getAnnIds(imgIds=image_id[i], iscrowd=0)
        anns = coco.loadAnns(annIds)
        print(images)
        print(annIds)
        print(anns)
        file_name = str(images[0]['file_name'])
        image = cv2.imread(imageFile + file_name)

        # image = cv2.imread(imageFile + anns. + '.jpg')
        print(imageFile + file_name)

        for n in range(len(anns)):
            final_mask = []
            x, y, w, h = anns[n]['bbox']
            x, y, w, h = int(x), int(y), int(w), int(h)
            contours = anns[n]['segmentation'][0]
            for j in range(0,len(contours),2):
                xl = contours[j]
                yl = contours[j+1]
                mas = [xl,yl]
                final_mask.append(mas)
            polygons = np.asarray([final_mask], np.int32)
            print(polygons)
            image = cv2.fillConvexPoly(image, polygons, (0, 0, 255)) 
            image = cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255))
#             image = cv2.drawContours(image,contours,-1,(0, 0, 255),5)
        cv2.imwrite(resultFile + file_name, image)
    print("生成图片存在{}".format(resultFile))

# %%
if __name__ == "__main__":
    # annFile = '../../data/preprocess/coco/chenzhou/annotations/json.json'
    # imageFile = '../../data/preprocess/coco/chenzhou/images/'
    # resultFile = '../../data/preprocess/coco/chenzhou/test/'
    annFile = '/root/workspace/Thyroid_Solid_Nodule/data/preprocess/chenzhou_aug/annotations/pseudo_images.json'
    imageFile = '/root/workspace/Thyroid_Solid_Nodule/data/preprocess/chenzhou_aug/images/'
    resultFile = '/root/workspace/Thyroid_Solid_Nodule/data/preprocess/chenzhou_aug/test/'
    if os.path.exists(resultFile) == False:
        os.makedirs(resultFile)
    showNimages(annFile, imageFile, resultFile)
# Out:
# loading annotations into memory...
# Done (t=0.38s)
# creating index...
# index created!
# [{'file_name': 'A1B1C1D1E1_15647281620180813THY11520180813163115220_A1B1C1D1E1_15647281620180813THY11520180813163115220T_6a007672-7ba8-4cfb-a228-85f06d08e8d8.jpg', 'id': 1, 'width': 1024, 'height': 768}]
# [2]
# [{'area': 11668, 'bbox': [494, 333, 139, 105], 'category_id': 1, 'id': 2, 'image_id': 300001, 'iscrowd': 0, 'segmentation': [[572, 437, 588, 434, 599, 430, 612, 422, 620, 415, 629, 401, 632, 391, 632, 379, 630, 371, 620, 355, 612, 347, 599, 339, 588, 335, 572, 332, 554, 332, 542, 334, 527, 339, 518, 344, 505, 355, 495, 371, 493, 379, 493, 391, 496, 401, 499, 407, 509, 418, 527, 430, 547, 436, 572, 437]]}]
# /root/workspace/Thyroid_Solid_Nodule/data/preprocess/chenzhou_aug/images/A1B1C1D1E1_15647281620180813THY11520180813163115220_A1B1C1D1E1_15647281620180813THY11520180813163115220T_6a007672-7ba8-4cfb-a228-85f06d08e8d8.jpg
# [[[572 437]
#   [588 434]
#   [599 430]
#   [612 422]
#   [620 415]
#   [629 401]
#   [632 391]
#   [632 379]
#   [630 371]
#   [620 355]
#   [612 347]
#   [599 339]
#   [588 335]
#   [572 332]
#   [554 332]
#   [542 334]
#   [527 339]
#   [518 344]
#   [505 355]
#   [495 371]
#   [493 379]
#   [493 391]
#   [496 401]
#   [499 407]
#   [509 418]
#   [527 430]
#   [547 436]
#   [572 437]]]
# [{'file_name': 'A4B1C3D2E2_71THY2620180726100802840_A4B1C3D2E2_71THY2620180726100802840V_f63c9385-5247-400f-b05f-58a2d84f9ebc.jpg', 'id': 304142, 'width': 1024, 'height': 768}]
# [5272]
# [{'area': 12348, 'bbox': [608, 394, 172, 93], 'category_id': 1, 'id': 5272, 'image_id': 304142, 'iscrowd': 0, 'segmentation': [[766, 464, 766, 415, 754, 406, 733, 398, 720, 395, 704, 393, 681, 393, 656, 397, 644, 401, 630, 407, 622, 413, 611, 424, 606, 436, 606, 444, 609, 453, 622, 466, 634, 474, 656, 482, 666, 484, 681, 486, 704, 486, 725, 483, 754, 473, 766, 464]]}]
# /root/workspace/Thyroid_Solid_Nodule/data/preprocess/chenzhou_aug/images/A4B1C3D2E2_71THY2620180726100802840_A4B1C3D2E2_71THY2620180726100802840V_f63c9385-5247-400f-b05f-58a2d84f9ebc.jpg
# [[[766 464]
#   [766 415]
#   [754 406]
#   [733 398]
#   [720 395]
#   [704 393]
#   [681 393]
#   [656 397]
#   [644 401]
#   [630 407]
#   [622 413]
#   [611 424]
#   [606 436]
#   [606 444]
#   [609 453]
#   [622 466]
#   [634 474]
#   [656 482]
#   [666 484]
#   [681 486]
#   [704 486]
#   [725 483]
#   [754 473]
#   [766 464]]]
# 生成图片存在/root/workspace/Thyroid_Solid_Nodule/data/preprocess/chenzhou_aug/test/
