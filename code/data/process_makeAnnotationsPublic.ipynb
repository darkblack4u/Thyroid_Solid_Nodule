# %%
"""
用于处理thyoid公开数据集数据，在原jpg文件中画出xml中所标注的结节区域

- thyoid目录
- maligns目录
- benigns目录
"""

import xml.etree.ElementTree as ET
import cv2
import os
import json
import numpy
import matplotlib.pyplot as plt
import imageio

# %%
"""
检查文件，参数（目录，后缀）
"""

def find_file_thyroid(directory, extension):
    print("[INFO] directory: " + directory)
    target_files = []
    for target_file in os.listdir(directory):
        if target_file.endswith(extension):
            print("[INFO] " + extension + "_file: " + directory + "/" + target_file)
            target_files += [target_file]
    target_files.sort()
    return target_files

# %%
"""
检查文件，参数（目录，后缀）
"""

def find_file(directory, extension):
    print("[INFO] directory: " + directory)
    target_files = []
    for target_dir in os.listdir(directory):
        for target_file in os.listdir(directory + "/" + target_dir):
            if target_file.endswith(extension):
                print("[INFO] " + extension + "_file: " + directory + "/" + target_dir + "/" + target_file)
                target_files += [target_file]
    target_files.sort()
    return target_files

# %%
"""
读取XML文件
"""
def read_xml_file(directory, filename,output_directory, prefix_filename):
    base_name=os.path.splitext(filename)[0]
    print("[INFO] read_xml_file: " + directory + "/" + base_name + "/" + filename)
    xml_tree = ET.parse(directory + "/" + base_name + "/" + filename)
    root = xml_tree.getroot()
    for mark in root.iter('mark'):
        # assert it has mark information
        if mark[1].text is not None:
            jpg_file = directory + "/" + base_name + "/" + mark[0].text + ".jpg"
            try:
                region_json = json.loads(mark[1].text)
                jpg_name = base_name + "_" + mark[0].text + ".jpg"
                output_jpg_name = prefix_filename + "_" + jpg_name
                # assert jpg file exist
                if os.path.exists(jpg_file):
                    jpg_output_file = directory + "/" + mark[0].text + "_mask.jpg"
                    print("[INFO] find_jpg_file: " + jpg_file)
                    annotation_image = create_image(jpg_file)
                    box_image = create_image(jpg_file)
                    image = imageio.imread(jpg_file)
                    height = image.shape[0]
                    width  = image.shape[1]
                    mask_image = numpy.zeros((height,width))
                    a = numpy.array([[int(region_json[0]['points'][0]['x']),int(region_json[0]['points'][0]['y'])]], numpy.int32)
                    for points in region_json[0]['points']:
                        a = numpy.append(a,[[int(points['x']), int(points['y'])]],axis=0)
                    cv2.fillConvexPoly(mask_image, a, (255, 255, 255))
                    pre_point = region_json[0]['points'][0]
                    for points in region_json[0]['points']:
                        if  pre_point != points:
                            cv2.line(annotation_image, (points['x'], points['y']), (pre_point['x'], pre_point['y']), (0, 0, 255))
                        pre_point = points
                    lmax = numpy.max(a[1:len(a)][:, 0])
                    lmin = numpy.min(a[1:len(a)][:, 0])
                    hmax = numpy.max(a[1:len(a)][:, 1])
                    hmin = numpy.min(a[1:len(a)][:, 1])
                    roi_image = image[hmin: hmax, lmin: lmax]
                    box_image = cv2.rectangle(box_image, (lmin, hmin), (lmax, hmax), color = (0, 255, 255), thickness = 3) # 图像，点集，是否闭合，颜色，线条粗细
#                     save_jpg_file(output_directory + "/annotation/" + output_jpg_name, annotation_image)
                    save_jpg_file(output_directory + "/mask/" + output_jpg_name, mask_image)
#                     save_jpg_file(output_directory + "/roi/" + output_jpg_name, roi_image)
                    save_jpg_file(output_directory + "/image/" + output_jpg_name, image)
#                     save_jpg_file(output_directory + "/box/" + output_jpg_name, box_image)
#                    cv2.namedWindow("Image")
#                    cv2.imshow("Image", label_image)
#                    cv2.waitKey(0)
#                    cv2.destroyAllWindows()
            except json.decoder.JSONDecodeError as e:
                print(e)

# %%
def read_xml_file_thyroid(directory, filename, output_directory):
    print("[INFO] read_xml_file: " + directory + "/" + filename)
    prefix_filename = filename[:-4]
    xml_tree = ET.parse(directory + "/" + filename)
    root = xml_tree.getroot()
    for mark in root.iter('mark'):
        if mark[1].text is not None:
            try:
                region_json = json.loads(mark[1].text)
                jpg_name = prefix_filename + "_" + mark[0].text + ".jpg"
                jpg_file = directory + "/" + jpg_name
                output_jpg_name = jpg_name
                if os.path.exists(jpg_file):
                    jpg_output_file = output_directory + "/" + jpg_name
                    print("[INFO] find_jpg_file: " + jpg_file)
                    annotation_image = create_image(jpg_file)
                    box_image = create_image(jpg_file)
                    image = imageio.imread(jpg_file)
                    height = image.shape[0]
                    width  = image.shape[1]
                    mask_image = numpy.zeros((height,width))
                    a = numpy.array([[int(region_json[0]['points'][0]['x']),int(region_json[0]['points'][0]['y'])]], numpy.int32)
                    for points in region_json[0]['points']:
                        a = numpy.append(a,[[int(points['x']), int(points['y'])]],axis=0)
                    cv2.fillConvexPoly(mask_image, a, (255, 255, 255))
                    pre_point = region_json[0]['points'][0]
                    for points in region_json[0]['points']:
                        if  pre_point != points:
                            cv2.line(annotation_image, (points['x'], points['y']), (pre_point['x'], pre_point['y']), (0, 0, 255))
                        pre_point = points
                    lmax = numpy.max(a[1:len(a)][:, 0])
                    lmin = numpy.min(a[1:len(a)][:, 0])
                    hmax = numpy.max(a[1:len(a)][:, 1])
                    hmin = numpy.min(a[1:len(a)][:, 1])
                    roi_image = image[hmin: hmax, lmin: lmax]
                    box_image = cv2.rectangle(box_image, (lmin, hmin), (lmax, hmax), color = (0, 255, 255), thickness = 3) # 图像，点集，是否闭合，颜色，线条粗细
#                     save_jpg_file("data/thyroid_mask/" + jpg_name, mask_image)
#                     save_jpg_file("data/thyroid_image/" + jpg_name, image)
#                     save_jpg_file(output_directory + "/annotation/" + output_jpg_name, annotation_image)
                    save_jpg_file(output_directory + "/mask/" + output_jpg_name, mask_image)
#                     save_jpg_file(output_directory + "/roi/" + output_jpg_name, roi_image)
                    save_jpg_file(output_directory + "/image/" + output_jpg_name, image)
#                     save_jpg_file(output_directory + "/box/" + output_jpg_name, box_image)

#                     return label_image,annotation
            except Exception as e:
                print(e)

# %%
def create_image(jpg_file):
    image = imageio.imread(jpg_file)
    height = image.shape[0]
    width = image.shape[1]
    new_image = cv2.resize(image, (width, height), interpolation=cv2.INTER_LINEAR)
    return new_image

# %%
def save_jpg_file(jpg_output_file, output_image):
    cv2.imwrite(jpg_output_file, output_image)

# %%
# 公开数据集
maligns_folder_name = '../../data/origin/public/maligns/maling'
benigns_folder_name = '../../data/origin/public/benigns/bening'
thyroid_folder_name = '../../data/origin/public/thyroid'

# folder_name=maligns_folder_name
# folder_name=benigns_folder_name
# folder_name=thyroid_folder_name

# 郴州数据输出目录
output_folder_name = '../../data/preprocess/public/'
# 标注图像输出目录
if os.path.exists(output_folder_name + "/annotation/") == False:
    os.makedirs(output_folder_name + "/annotation/")
# mask图像输出目录
if os.path.exists(output_folder_name + "/mask/") == False:
    os.makedirs(output_folder_name + "/mask/")
# ROI图像输出目录
if os.path.exists(output_folder_name + "/roi/") == False:
    os.makedirs(output_folder_name + "/roi/")
# 原始图像输出目录
if os.path.exists(output_folder_name + "/box/") == False:
    os.makedirs(output_folder_name + "/box/")
# 原始图像输出目录
if os.path.exists(output_folder_name + "/image/") == False:
    os.makedirs(output_folder_name + "/image/")
    
for folder_name in [maligns_folder_name, benigns_folder_name, thyroid_folder_name]:
    if folder_name == thyroid_folder_name:
        xml_files = find_file_thyroid(folder_name, '.xml')
    else:
        xml_files = find_file(folder_name, '.xml')
    for xml_file in xml_files:
        if folder_name == maligns_folder_name:
            read_xml_file(folder_name, xml_file, output_folder_name, "maligns")
        if folder_name == benigns_folder_name:
            read_xml_file(folder_name, xml_file, output_folder_name, "benigns")
        if folder_name == thyroid_folder_name:
            read_xml_file_thyroid(folder_name, xml_file, output_folder_name)

# image = misc.imread("data/thyroid_mask/maligns_562_1.jpg")
# print(image[100][440])
# plt.imshow(image)
# Out:
# [INFO] directory: ../../data/origin/public/maligns/maling
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/576/576.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/569/569.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/631/631.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/608/608.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/552/552.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/564/564.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/566/566.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/619/619.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/625/625.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/616/616.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/613/613.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/639/639.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/644/644.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/571/571.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/601/601.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/629/629.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/551/551.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/640/640.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/572/572.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/555/555.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/612/612.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/638/638.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/610/610.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/549/549.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/563/563.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/622/622.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/554/554.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/646/646.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/623/623.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/545/545.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/609/609.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/606/606.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/635/635.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/565/565.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/568/568.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/561/561.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/567/567.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/618/618.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/570/570.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/624/624.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/562/562.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/574/574.xml
# [INFO] .xml_file: ../../data/origin/public/maligns/maling/550/550.xml
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/545/545.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/545/1.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/545/2.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/549/549.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/549/1.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/549/2.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/550/550.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/550/2.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/550/1.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/550/3.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/551/551.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/551/3.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/551/2.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/551/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/552/552.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/552/2.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/552/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/554/554.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/554/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/555/555.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/555/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/561/561.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/561/1.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/561/2.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/562/562.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/562/2.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/562/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/563/563.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/563/1.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/563/2.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/564/564.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/564/3.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/564/5.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/564/1.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/564/2.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/564/4.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/565/565.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/565/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/566/566.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/566/1.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/566/2.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/567/567.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/567/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/568/568.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/568/1.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/568/2.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/569/569.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/569/2.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/570/570.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/570/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/571/571.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/571/2.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/571/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/572/572.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/572/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/574/574.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/574/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/576/576.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/576/1.jpg
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/576/2.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/601/601.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/601/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/606/606.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/606/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/608/608.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/608/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/609/609.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/609/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/610/610.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/610/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/612/612.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/612/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/613/613.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/613/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/616/616.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/616/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/618/618.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/618/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/619/619.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/619/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/622/622.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/622/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/623/623.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/623/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/624/624.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/624/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/625/625.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling/625/1.jpg
# [INFO] read_xml_file: ../../data/origin/public/maligns/maling/629/629.xml
# [INFO] find_jpg_file: ../../data/origin/public/maligns/maling